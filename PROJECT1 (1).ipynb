# %%
! pip install kaggle

# %%
# !kaggle  datasets list -s "retail-orders"
# Out:
# ref                                                             title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# gabrielsantello/wholesale-and-retail-orders-dataset             Wholesale & Retail Orders Dataset                     3MB  2023-09-19 09:31:40           2766         43  1.0
# ankitbansal06/retail-orders                                     Retail Orders                                       200KB  2024-04-13 08:31:36          11007         27  0.47058824
# zusmani/pakistans-largest-ecommerce-dataset                     Pakistan's Largest E-Commerce Dataset                14MB  2021-01-19 11:42:57          12752        348  0.9705882
# ...

# %%
# !kaggle datasets download -d "ankitbansal06/retail-orders"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# retail-orders.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

# %%
with zipfile.ZipFile("retail-orders.zip","r") as file:
    file.extractall("sakth")

# %%
import os
os.listdir("sakth")
# Out:
# ['orders.csv']

# %%
import pandas as pd

# %%
df=pd.read_csv("sakth/orders.csv")

# %%
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_ID  cost_price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_Id          9994 non-null   int64
#  1   Order_Date        9994 non-null   datetime64[ns]
#  2   Ship_Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal_Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub_Category      9994 non-null   object
#  11  Product_ID        9994 non-null   object
#  12  cost_price        9994 non-null   int64
#  13  List_Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount_Percent  9994 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_ID', 'cost_price', 'List_Price', 'Quantity',
#        'Discount_Percent'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 16)

# %%
df.isnull().sum()
# Out:
# Order_Id            0
# Order_Date          0
# Ship_Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal_Code         0
# Region              0
# Category            0
# Sub_Category        0
# Product_ID          0
# cost_price          0
# List_Price          0
# Quantity            0
# Discount_Percent    0
# dtype: int64

# %%
df.fillna({'Ship Mode':0},inplace=True)

# %%
df.isnull().sum()
# Out:
# Order_Id            0
# Order_Date          0
# Ship_Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal_Code         0
# Region              0
# Category            0
# Sub_Category        0
# Product_ID          0
# cost_price          0
# List_Price          0
# Quantity            0
# Discount_Percent    0
# dtype: int64

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_Id          9994 non-null   int64
#  1   Order_Date        9994 non-null   datetime64[ns]
#  2   Ship_Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal_Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub_Category      9994 non-null   object
#  11  Product_ID        9994 non-null   object
#  12  cost_price        9994 non-null   int64
#  13  List_Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount_Percent  9994 non-null   int64
# ...

# %%
df.rename(columns={'Order Id':'Order_Id','Order Date':'Order_Date','Ship Mode':'Ship_Mode','Postal Code':'Postal_Code','Sub Category':"Sub_Category",'Product Id':"Product_ID","cost price":"cost_price","List Price":"List_Price",'Discount Percent':'Discount_Percent'},inplace=True)

# %%
df['Ship_Mode']=df['Ship_Mode'].str.rstrip()

# %%
df['Segment']=df['Segment'].str.rstrip()

# %%
df['Country']=df['Country'].str.rstrip()

# %%
df['City']=df['City'].str.rstrip()

# %%
df['State']=df['State'].str.rstrip()

# %%
df['Region']=df['Region'].str.rstrip()

# %%
df['Category']=df['Category'].str.rstrip()

# %%
df['Sub_Category']=df['Sub_Category'].str.rstrip()

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df['Discount']=df['List_Price']-df['cost_price']//df['List_Price']*100

# %%
df['Discount']
# Out:
# 0       260.0
# 1       730.0
# 2       -90.0
# 3       960.0
# 4       -80.0
#         ...
# 9989    -70.0
# 9990     90.0
# 9991    260.0
# 9992    -70.0
# 9993    240.0
# Name: Discount, Length: 9994, dtype: float64

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df['Profit']=df['List_Price']-df['cost_price']

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df['Sales']=df['List_Price']*df['Quantity']

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_Id          9994 non-null   int64
#  1   Order_Date        9994 non-null   datetime64[ns]
#  2   Ship_Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal_Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub_Category      9994 non-null   object
#  11  Product_ID        9994 non-null   object
#  12  cost_price        9994 non-null   int64
#  13  List_Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount_Percent  9994 non-null   int64
# ...

# %%
df_order=df.iloc[:,:9]

# %%
df_order['Order_Date']=df_order['Order_Date'].astype('object')
df_order["Order_Date"]=pd.to_datetime(df_order['Order_Date'])

# %%
df_order
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region
# 0           Henderson    Kentucky        42420  South
# ...

# %%
df_orders=df.iloc[:,9:]

# %%
df_orders
# Out:
#              Category Sub_Category       Product_ID  cost_price  List_Price  \
# 0           Furniture    Bookcases  FUR-BO-10001798         240         260
# 1           Furniture       Chairs  FUR-CH-10000454         600         730
# 2     Office Supplies       Labels  OFF-LA-10000240          10          10
# 3           Furniture       Tables  FUR-TA-10000577         780         960
# 4     Office Supplies      Storage  OFF-ST-10000760          20          20
# ...               ...          ...              ...         ...         ...
# 9989        Furniture  Furnishings  FUR-FU-10001889          30          30
# 9990        Furniture  Furnishings  FUR-FU-10000747          70          90
# 9991       Technology       Phones  TEC-PH-10003645         220         260
# 9992  Office Supplies        Paper  OFF-PA-10004041          30          30
# 9993  Office Supplies   Appliances  OFF-AP-10002684         210         240
#
# ...

# %%
df_orders.to_csv(r"C:\Users\sakth\Documents\Desktop\df_orders.csv")

# %%
df_order.to_csv(r"C:\Users\sakth\Documents\Desktop\df_order.csv")

# %%
df1=pd.read_csv(r"C:\Users\sakth\Documents\Desktop\df_order.csv")

# %%
df1
# Out:
#       Unnamed: 0  Order_Id  Order_Date       Ship_Mode    Segment  \
# 0              0         1  2023-03-01    Second Class   Consumer
# 1              1         2  2023-08-15    Second Class   Consumer
# 2              2         3  2023-01-10    Second Class  Corporate
# 3              3         4  2022-06-18  Standard Class   Consumer
# 4              4         5  2022-07-13  Standard Class   Consumer
# ...          ...       ...         ...             ...        ...
# 9989        9989      9990  2023-02-18    Second Class   Consumer
# 9990        9990      9991  2023-03-17  Standard Class   Consumer
# 9991        9991      9992  2022-08-07  Standard Class   Consumer
# 9992        9992      9993  2022-11-19  Standard Class   Consumer
# 9993        9993      9994  2022-07-17    Second Class   Consumer
#
#             Country             City       State  Postal_Code Region
# 0     United States        Henderson    Kentucky        42420  South
# ...

# %%
df["City"]
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
df2=pd.read_csv(r"C:\Users\sakth\Documents\Desktop\df_orders.csv")

# %%
df2
# Out:
#       Unnamed: 0         Category Sub_Category       Product_ID  cost_price  \
# 0              0        Furniture    Bookcases  FUR-BO-10001798         240
# 1              1        Furniture       Chairs  FUR-CH-10000454         600
# 2              2  Office Supplies       Labels  OFF-LA-10000240          10
# 3              3        Furniture       Tables  FUR-TA-10000577         780
# 4              4  Office Supplies      Storage  OFF-ST-10000760          20
# ...          ...              ...          ...              ...         ...
# 9989        9989        Furniture  Furnishings  FUR-FU-10001889          30
# 9990        9990        Furniture  Furnishings  FUR-FU-10000747          70
# 9991        9991       Technology       Phones  TEC-PH-10003645         220
# 9992        9992  Office Supplies        Paper  OFF-PA-10004041          30
# 9993        9993  Office Supplies   Appliances  OFF-AP-10002684         210
#
# ...
